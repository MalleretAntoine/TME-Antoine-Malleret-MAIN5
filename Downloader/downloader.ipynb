# %%
#Au secours

# %% [markdown]
# Dechiffrer son code : mi+yi = ci , |ci|= 1 octet
#
# Claire commun avec le robot nettoyeur
# m1 et mi sur les 1er octets.
# On peut réccup les yi sur les 1er octets
#
# Attaque :
# On réccupère X0 , tout les Xi, tout les yi, tout les mi donc le clair
#
# Vecteur connues : a,p=2**128,l=120, k=2**l, yi i de 0 à n-1
# Xi inconnues de 0 à n-1
#
#
# Explication:
# X0 seed
# Xi+1 = aXi mod p
# Yi=partie entière(Xi/k)
#
# on cherche les Xi equivaut à cherche X0
#
# X0=seed
#
# aisin par reccurence :
# X=(x0,ax0 mod p... a**n-1 X0 mod )
# c'est à dire si on fait l'equivalent du modulot :
#
# X=(x0,ax0+ q1*p... a**n-1 X0 +qn*p)
#
# Reseau euclidien :
# Soit B dans Z**n*m
#
# Le réseau engendré par B est :
# L(B)={xEZ**n , il existe yEZ**n yB=x}
#
# Soit xEZ**n x E L(B), il existe yEZ**n yB=x
#
# donc
# X=(X0,q1,...,qn)*matrice()
#
# matrice nommée B
# faire la transformation B en B1 avec lll avant de faire svp
#
# On connait les Yi donc on connait les k Yi
# k Y0 : Y0 000000...0
# k Y1 : Y1 00000...0
# .
# .
# .
# k Yn-1 : yn-1 0000...000
#
# donc kY=(ky0,...kyn)
